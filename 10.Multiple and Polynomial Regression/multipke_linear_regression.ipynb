# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
df = pd.DataFrame({
    'Square foot':[1500,2000,1200,2500,1800,1600,2200,1400,1900,2100,2800,1300,1700,2400,1100],
    'Bedrooms' : [3,4,2,4,3,3,4,2,3,4,5,2,3,4,2],
    'House_age': [10,5,20,2,15,8,1,12,7,4,1,25,11,3,30],
    'Price' : [300,450,200,550,350,320,480,280,380,420,600,180,340,500,150]}
)
df.head()
# Out:
#    Square foot  Bedrooms  House_age  Price
# 0         1500         3         10    300
# 1         2000         4          5    450
# 2         1200         2         20    200
# 3         2500         4          2    550
# 4         1800         3         15    350

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot = True)
plt.title("correlation")
plt.show()

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot = True, cmap = "coolwarm")
plt.title("correlation")
plt.show()

# %%
x = df[["Square foot","Bedrooms","House_age"]]
y = df["Price"]
model = LinearRegression().fit(x,y)
model
print(f"Intercept(c):{model.intercept_:.2f}")
print(f"cofficent:{model.coef_}")
# Out:
# Intercept(c):27.83
# cofficent:[ 0.19501267  6.34433793 -3.79712716]

# %%
predicted_house_price = model.predict([[1000,2,50]])
predicted_house_price
# Out:
# c:\Users\Jagerna Shrestha\OneDrive\Desktop\datascience\10.Multiple and Polynomial Regression\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45.67038743])
