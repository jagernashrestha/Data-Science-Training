# %%
import pandas as pd 
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

#create a simple series(e.g. price in Lakhs)
prices = pd.series([10,12,15,14,50], name = "Prices")
print(prices)

#Sckit-learn expects a 2D array, so we reshape (-1,1)
#Converts 1D data to 2D data

data_2d = prices.values.reshape(-1,1)
print(data_2d)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       2 from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
#       4 #create a simple series(e.g. price in Lakhs)
# ----> 5 prices = pd.series([10,12,15,14,50], name = "Prices")
#       6 print(prices)
#       8 #Sckit-learn expects a 2D array, so we reshape (-1,1)
#       9 #Converts 1D data to 2D data
#
# AttributeError: module 'pandas' has no attribute 'series'
